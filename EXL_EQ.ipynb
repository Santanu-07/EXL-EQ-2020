# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel (r'C:\Users\Santanu Das\Downloads\EXL_EQ_2020_Train_datasets.xlsx', sheet_name='Train Sample')
df
# Out:
#         cust_id   var1  var2  var3   var4  var5  var6  var7  var8     var9  \
# 0        100001   2667     0     0   1768     0     4     0     2   291016
# 1        100002    435     0     0    515     0     3     0     0   137667
# 2        100003   1520     0     0   2280     0     6     0     4   301567
# 3        100004   4393     0     1   5731     0     8     1    27   436735
# 4        100005   3587     0     0   2493     0     7     0     7   314970
# 5        100006   1071     0     1   6840     0     8     0    33   345363
# 6        100007   3079     0     0   3105     0     7     0     7   331691
# 7        100008   1529     0     1   7506     1     3     0    53   244942
# 8        100009     95     0     0     84     0     0     0     0    60845
# 9        100010   7784     0     1   5899     1     9     2    30   507727
# 10       100011   3536     0     0   2466     0     7     0     5   320887
# ...

# %%
df.self_service_platform[df.self_service_platform == 'Desktop'] = 1
df.self_service_platform[df.self_service_platform == 'Mobile App'] = 2
df.self_service_platform[df.self_service_platform == 'Mobile Web'] = 3
df.self_service_platform[df.self_service_platform == 'STB'] = 4
df.var40[df.var40 == 'Y'] = 1
df.var40[df.var40 == 'N'] = 0
df.var37[df.var37 == 'Y'] = 1
df.var37[df.var37 == 'N'] = 0
df
# Out:
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
exl = df.drop([ 'var30','var33','var34','var35','var36','var38','var37','var39'], axis=1)
exl
# Out:
#         cust_id   var1  var2  var3   var4  var5  var6  var7  var8     var9  \
# 0        100001   2667     0     0   1768     0     4     0     2   291016
# 1        100002    435     0     0    515     0     3     0     0   137667
# 2        100003   1520     0     0   2280     0     6     0     4   301567
# 3        100004   4393     0     1   5731     0     8     1    27   436735
# 4        100005   3587     0     0   2493     0     7     0     7   314970
# 5        100006   1071     0     1   6840     0     8     0    33   345363
# 6        100007   3079     0     0   3105     0     7     0     7   331691
# 7        100008   1529     0     1   7506     1     3     0    53   244942
# 8        100009     95     0     0     84     0     0     0     0    60845
# 9        100010   7784     0     1   5899     1     9     2    30   507727
# 10       100011   3536     0     0   2466     0     7     0     5   320887
# ...

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
exl = exl.fillna(exl[['var24']].mean(axis = 0))
exl
# Out:
#         cust_id   var1  var2  var3   var4  var5  var6  var7  var8     var9  \
# 0        100001   2667     0     0   1768     0     4     0     2   291016
# 1        100002    435     0     0    515     0     3     0     0   137667
# 2        100003   1520     0     0   2280     0     6     0     4   301567
# 3        100004   4393     0     1   5731     0     8     1    27   436735
# 4        100005   3587     0     0   2493     0     7     0     7   314970
# 5        100006   1071     0     1   6840     0     8     0    33   345363
# 6        100007   3079     0     0   3105     0     7     0     7   331691
# 7        100008   1529     0     1   7506     1     3     0    53   244942
# 8        100009     95     0     0     84     0     0     0     0    60845
# 9        100010   7784     0     1   5899     1     9     2    30   507727
# 10       100011   3536     0     0   2466     0     7     0     5   320887
# ...

# %%
exl = exl.fillna(exl[['var24']].mean(axis = 0))
X = exl[exl.columns[1:29]]
y = exl['self_service_platform']
y=y.astype('int')
np.nan_to_num(X)
X
# Out:
#          var1  var2  var3   var4  var5  var6  var7  var8     var9  var10  ...  \
# 0        2667     0     0   1768     0     4     0     2   291016      0  ...
# 1         435     0     0    515     0     3     0     0   137667      0  ...
# 2        1520     0     0   2280     0     6     0     4   301567      0  ...
# 3        4393     0     1   5731     0     8     1    27   436735      1  ...
# 4        3587     0     0   2493     0     7     0     7   314970      0  ...
# 5        1071     0     1   6840     0     8     0    33   345363      1  ...
# 6        3079     0     0   3105     0     7     0     7   331691      0  ...
# 7        1529     0     1   7506     1     3     0    53   244942     11  ...
# 8          95     0     0     84     0     0     0     0    60845      0  ...
# 9        7784     0     1   5899     1     9     2    30   507727      1  ...
# 10       3536     0     0   2466     0     7     0     5   320887      0  ...
# ...

# %%
df1 = pd.read_excel (r'C:\Users\Santanu Das\Downloads\EXL_EQ_2020_Test_Datasets.xlsx', sheet_name='Test sample')
df1
# Out:
#         cust_id   var1  var2  var3   var4  var5  var6  var7  var8     var9  \
# 0        400001   2871     0     0   1925     0     7     0     1   238388
# 1        400002    562     0     0    197     0     3     0     0   136782
# 2        400003   4350     0     1   5664     0     8     1    25   336602
# 3        400004   7580     0     1   6093     0     8     4    31   501694
# 4        400005     58     0     0     53     0     0     0     0    87465
# 5        400006   4202     2     2  29300     5     8    32    60  1259358
# 6        400007   1234     0     0   8098     0     7     0    28   318965
# 7        400008    685     0     0   1183     0     4     0     1   170981
# 8        400009    311     0     0    445     0     3     0     0   146257
# 9        400010   2273     0     0   1483     0     4     0     1   289118
# 10       400011    220     0     0    141     0     1     0     0   107893
# ...

# %%
exl_test = df1.drop(['var30','var33','var34','var35','var36','var38','var39'],axis=1)
df1.var40[df1.var40 == 'Y'] = 1
df1.var40[df1.var40 == 'N'] = 0
df1.var37[df1.var37 == 'Y'] = 1
df1.var37[df1.var37 == 'N'] = 0
exl_test = exl_test.fillna(exl_test[['var24']].mean(axis = 0))
exl_test["var37"].fillna( method ='ffill', inplace = True)
exl_test = exl_test[exl_test.columns[1:29]]
exl_test
# Out:
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.01)

# %%
len(X_train)
# Out:
# 297000

# %%
len(X_test)
# Out:
# 3000

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=0)

# %%
exl.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Santanu Das\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
X.shape
# Out:
# (300000, 28)

# %%
y.shape
# Out:
# (300000,)

# %%
X_test = exl_test

# %%
result  = model.predict(X_test)

# %%
result
# Out:
# array([1, 1, 2, ..., 2, 1, 1])

# %%
import numpy as np
import pandas as pd
result = pd.DataFrame(result, columns=['predictions']).to_csv('prediction.csv')
